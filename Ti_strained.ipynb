# %%
# Read separate files (no header)
from sklearn.metrics import r2_score
dft  = pd.read_csv("forces_dft.csv", header=None)[0]
pot1 = pd.read_csv("forces1.csv", header=None)[0]
pot2 = pd.read_csv("forces2.csv", header=None)[0]
pot3 = pd.read_csv("forces3.csv", header=None)[0]

# Create dataframe exactly like the original code expects
df = pd.DataFrame({
    'DFT': dft,
    'POTENTIAL1': pot1,
    'POTENTIAL2': pot2,
    'POTENTIAL3': pot3
})
dft_ref = df['DFT']
potentials = ['POTENTIAL1', 'POTENTIAL2', 'POTENTIAL3']

# Calculate R² scores
r2_results = {}

for pot in potentials:
    score = r2_score(dft_ref, df[pot])
    r2_results[pot] = score
    print(f"{pot} R² Score: {score:.8f}")

best_potential = max(r2_results, key=r2_results.get)
print(f"\nConclusion: {best_potential} is the best fit model.")

# Generate comparison subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, pot in enumerate(potentials):

    axes[i].scatter(
        dft_ref,
        df[pot],
        color='blue',
        alpha=0.7,
        label='Data points'
    )

    min_val = min(dft_ref.min(), df[pot].min())
    max_val = max(dft_ref.max(), df[pot].max())

    axes[i].plot(
        [min_val, max_val],
        [min_val, max_val],
        'r--',
        label='Perfect Fit (y=x)'
    )

    axes[i].set_title(
        f"{pot}\n$R^2$ Score: {r2_results[pot]:.4f}",
        fontsize=12
    )

    axes[i].set_xlabel('DFT Reference Value', fontsize=10)
    axes[i].set_ylabel(f'{pot} Predicted Value', fontsize=10)
    axes[i].grid(True, linestyle=':', alpha=0.6)
    axes[i].legend()

plt.tight_layout()
plt.show()
# Out:
# POTENTIAL1 R² Score: -3.80194023
# POTENTIAL2 R² Score: -2.19046039
# POTENTIAL3 R² Score: -0.02500402
#
# Conclusion: POTENTIAL3 is the best fit model.

# %%
# Read separate files (no header)
from sklearn.metrics import r2_score
dft  = pd.read_csv("Formation_energy_dft.csv", header=None)[0]
pot1 = pd.read_csv("Formation_energy1.csv", header=None)[0]
pot2 = pd.read_csv("Formation_energy2.csv", header=None)[0]
pot3 = pd.read_csv("Formation_energy3.csv", header=None)[0]

# Create dataframe exactly like the original code expects
df = pd.DataFrame({
    'DFT': dft,
    'POTENTIAL1': pot1,
    'POTENTIAL2': pot2,
    'POTENTIAL3': pot3
})
dft_ref = df['DFT']
potentials = ['POTENTIAL1', 'POTENTIAL2', 'POTENTIAL3']

# Calculate R² scores
r2_results = {}

for pot in potentials:
    score = r2_score(dft_ref, df[pot])
    r2_results[pot] = score
    print(f"{pot} R² Score: {score:.8f}")

best_potential = max(r2_results, key=r2_results.get)
print(f"\nConclusion: {best_potential} is the best fit model.")

# Generate comparison subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, pot in enumerate(potentials):

    axes[i].scatter(
        dft_ref,
        df[pot],
        color='blue',
        alpha=0.7,
        label='Data points'
    )

    min_val = min(dft_ref.min(), df[pot].min())
    max_val = max(dft_ref.max(), df[pot].max())

    axes[i].plot(
        [min_val, max_val],
        [min_val, max_val],
        'r--',
        label='Perfect Fit (y=x)'
    )

    axes[i].set_title(
        f"{pot}\n$R^2$ Score: {r2_results[pot]:.4f}",
        fontsize=12
    )

    axes[i].set_xlabel('DFT Reference Value', fontsize=10)
    axes[i].set_ylabel(f'{pot} Predicted Value', fontsize=10)
    axes[i].grid(True, linestyle=':', alpha=0.6)
    axes[i].legend()

plt.tight_layout()
plt.show()
# Out:
# POTENTIAL1 R² Score: -5817.47686507
# POTENTIAL2 R² Score: -61591.36645597
# POTENTIAL3 R² Score: -44603.04676793
#
# Conclusion: POTENTIAL1 is the best fit model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Read data
dft  = pd.read_csv("dft_forces.csv", header=None)[0]
pot1 = pd.read_csv("0.75_0.25_after_forces.csv", header=None)[0]
pot2 = pd.read_csv("1_0_after_forces.csv", header=None)[0]
pot3 = pd.read_csv("100_10_after_forces.csv", header=None)[0]
pot4 = pd.read_csv("0.4_0.6_after_forces.csv", header=None)[0]

# Create DataFrame
df = pd.DataFrame({
    'DFT': dft,
    'POTENTIAL1': pot1,
    'POTENTIAL2': pot2,
    'POTENTIAL3': pot3,
    'POTENTIAL4': pot4
})

dft_ref = df['DFT']
potentials = ['POTENTIAL1', 'POTENTIAL2', 'POTENTIAL3', 'POTENTIAL4']

# Calculate R² scores
r2_results = {}

for pot in potentials:
    score = r2_score(dft_ref, df[pot])
    r2_results[pot] = score
    print(f"{pot} R² Score: {score:.8f}")

best_potential = max(r2_results, key=r2_results.get)
print(f"\nConclusion: {best_potential} is the best fit model.")

# Create 4 subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

for i, pot in enumerate(potentials):

    axes[i].scatter(
        dft_ref,
        df[pot],
        color='blue',
        alpha=0.7,
        s=15,
        label='Data'
    )

    min_val = min(dft_ref.min(), df[pot].min())
    max_val = max(dft_ref.max(), df[pot].max())

    axes[i].plot(
        [min_val, max_val],
        [min_val, max_val],
        'r--',
        linewidth=2,
        label='y = x'
    )

    axes[i].set_title(f"{pot}\n$R^2$ = {r2_results[pot]:.6f}")
    axes[i].set_xlabel("DFT Force")
    axes[i].set_ylabel(f"{pot} Force")
    axes[i].grid(True, linestyle=':')
    axes[i].legend()

plt.tight_layout()
plt.show()
# Out:
# POTENTIAL1 R² Score: 0.44292973
# POTENTIAL2 R² Score: -708996.20003514
# POTENTIAL3 R² Score: 0.01130274
# POTENTIAL4 R² Score: -3.40004051
#
# Conclusion: POTENTIAL1 is the best fit model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Read data
dft  = pd.read_csv("dft_forces.csv", header=None)[0]
pot1 = pd.read_csv("0.75_0.25_forces.csv", header=None)[0]
pot2 = pd.read_csv("1_0_forces.csv", header=None)[0]
pot3 = pd.read_csv("100_10_forces.csv", header=None)[0]
pot4 = pd.read_csv("0.4_0.6_forces.csv", header=None)[0]

# Create DataFrame
df = pd.DataFrame({
    'DFT': dft,
    'POTENTIAL1': pot1,
    'POTENTIAL2': pot2,
    'POTENTIAL3': pot3,
    'POTENTIAL4': pot4
})

dft_ref = df['DFT']
potentials = ['POTENTIAL1', 'POTENTIAL2', 'POTENTIAL3', 'POTENTIAL4']

# Calculate R² scores
r2_results = {}

for pot in potentials:
    score = r2_score(dft_ref, df[pot])
    r2_results[pot] = score
    print(f"{pot} R² Score: {score:.8f}")

best_potential = max(r2_results, key=r2_results.get)
print(f"\nConclusion: {best_potential} is the best fit model.")

# Create 4 subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

for i, pot in enumerate(potentials):

    axes[i].scatter(
        dft_ref,
        df[pot],
        color='blue',
        alpha=0.7,
        s=15,
        label='Data'
    )

    min_val = min(dft_ref.min(), df[pot].min())
    max_val = max(dft_ref.max(), df[pot].max())

    axes[i].plot(
        [min_val, max_val],
        [min_val, max_val],
        'r--',
        linewidth=2,
        label='y = x'
    )

    axes[i].set_title(f"{pot}\n$R^2$ = {r2_results[pot]:.6f}")
    axes[i].set_xlabel("DFT Force")
    axes[i].set_ylabel(f"{pot} Force")
    axes[i].grid(True, linestyle=':')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Read data
dft  = pd.read_csv("energy_dft.csv", header=None)[0]
pot1 = pd.read_csv("0.75_0.25_energy.csv", header=None)[0]
pot2 = pd.read_csv("1_0_energy.csv", header=None)[0]
pot3 = pd.read_csv("100_10_energy.csv", header=None)[0]
pot4 = pd.read_csv("0.4_0.6_energy.csv", header=None)[0]

# Create DataFrame
df = pd.DataFrame({
    'DFT': dft,
    'POTENTIAL1': pot1,
    'POTENTIAL2': pot2,
    'POTENTIAL3': pot3,
    'POTENTIAL4': pot4
})

dft_ref = df['DFT']
potentials = ['POTENTIAL1', 'POTENTIAL2', 'POTENTIAL3', 'POTENTIAL4']

# Calculate R² scores
r2_results = {}

for pot in potentials:
    score = r2_score(dft_ref, df[pot])
    r2_results[pot] = score
    print(f"{pot} R² Score: {score:.8f}")

best_potential = max(r2_results, key=r2_results.get)
print(f"\nConclusion: {best_potential} is the best fit model.")

# Create 4 subplots
fig, axes = plt.subplots(2, 2, figsize=(8, 6))
axes = axes.flatten()

for i, pot in enumerate(potentials):

    axes[i].scatter(
        dft_ref,
        df[pot],
        color='blue',
        alpha=0.7,
        s=15,
        label='Data'
    )

    min_val = min(dft_ref.min(), df[pot].min())
    max_val = max(dft_ref.max(), df[pot].max())

    axes[i].plot(
        [min_val, max_val],
        [min_val, max_val],
        'r--',
        linewidth=2,
        label='y = x'
    )

    axes[i].set_title(f"{pot}\n$R^2$ = {r2_results[pot]:.6f}")
    axes[i].set_xlabel("DFT Force")
    axes[i].set_ylabel(f"{pot} Force")
    axes[i].grid(True, linestyle=':')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Read data
dft  = pd.read_csv("energy_dft.csv", header=None)[0]
pot1 = pd.read_csv("0.75_0.25_after_energy.csv", header=None)[0]
pot2 = pd.read_csv("1_0_after_energy.csv", header=None)[0]
pot3 = pd.read_csv("100_10_after_energy.csv", header=None)[0]
pot4 = pd.read_csv("0.4_0.6_after_energy.csv", header=None)[0]

# Create DataFrame
df = pd.DataFrame({
    'DFT': dft,
    'POTENTIAL1': pot1,
    'POTENTIAL2': pot2,
    'POTENTIAL3': pot3,
    'POTENTIAL4': pot4
})

dft_ref = df['DFT']
potentials = ['POTENTIAL1', 'POTENTIAL2', 'POTENTIAL3', 'POTENTIAL4']

# Calculate R² scores
r2_results = {}

for pot in potentials:
    score = r2_score(dft_ref, df[pot])
    r2_results[pot] = score
    print(f"{pot} R² Score: {score:.8f}")

best_potential = max(r2_results, key=r2_results.get)
print(f"\nConclusion: {best_potential} is the best fit model.")

# Create 4 subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

for i, pot in enumerate(potentials):

    axes[i].scatter(
        dft_ref,
        df[pot],
        color='blue',
        alpha=0.7,
        s=15,
        label='Data'
    )

    min_val = min(dft_ref.min(), df[pot].min())
    max_val = max(dft_ref.max(), df[pot].max())

    axes[i].plot(
        [min_val, max_val],
        [min_val, max_val],
        'r--',
        linewidth=2,
        label='y = x'
    )

    axes[i].set_title(f"{pot}\n$R^2$ = {r2_results[pot]:.6f}")
    axes[i].set_xlabel("DFT Force")
    axes[i].set_ylabel(f"{pot} Force")
    axes[i].grid(True, linestyle=':')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Read data
dft  = pd.read_csv("energy_dft_formation_final.csv", header=None)[0]
pot1 = pd.read_csv("0.75_0.25_energy_formation.csv", header=None)[0]
pot2 = pd.read_csv("1_0_energy_formation.csv", header=None)[0]
pot3 = pd.read_csv("100_10_energy_formation.csv", header=None)[0]
pot4 = pd.read_csv("0.4_0.6_energy_formation.csv", header=None)[0]

# Create DataFrame
df = pd.DataFrame({
    'DFT': dft,
    'POTENTIAL1': pot1,
    'POTENTIAL2': pot2,
    'POTENTIAL3': pot3,
    'POTENTIAL4': pot4
})

dft_ref = df['DFT']
potentials = ['POTENTIAL1', 'POTENTIAL2', 'POTENTIAL3', 'POTENTIAL4']

# Calculate R² scores
r2_results = {}

for pot in potentials:
    score = r2_score(dft_ref, df[pot])
    r2_results[pot] = score
    print(f"{pot} R² Score: {score:.8f}")

best_potential = max(r2_results, key=r2_results.get)
print(f"\nConclusion: {best_potential} is the best fit model.")

# Create 4 subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

for i, pot in enumerate(potentials):

    axes[i].scatter(
        dft_ref,
        df[pot],
        color='blue',
        alpha=0.7,
        s=15,
        label='Data'
    )

    min_val = min(dft_ref.min(), df[pot].min())
    max_val = max(dft_ref.max(), df[pot].max())

    axes[i].plot(
        [min_val, max_val],
        [min_val, max_val],
        'r--',
        linewidth=2,
        label='y = x'
    )

    axes[i].set_title(f"{pot}\n$R^2$ = {r2_results[pot]:.6f}")
    axes[i].set_xlabel("DFT Force")
    axes[i].set_ylabel(f"{pot} Force")
    axes[i].grid(True, linestyle=':')
    axes[i].legend()

plt.tight_layout()
plt.show()
# Out:
# POTENTIAL1 R² Score: 0.94231164
# POTENTIAL2 R² Score: -70645.53904310
# POTENTIAL3 R² Score: -0.16383602
# POTENTIAL4 R² Score: 0.97401163
#
# Conclusion: POTENTIAL4 is the best fit model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Read data
dft  = pd.read_csv("energy_dft_formation_final.csv", header=None)[0]
pot1 = pd.read_csv("0.75_0.25_after_energy_formation.csv", header=None)[0]
pot2 = pd.read_csv("1_0_after_energy_formation.csv", header=None)[0]
pot3 = pd.read_csv("100_10_after_energy_formation.csv", header=None)[0]
pot4 = pd.read_csv("0.4_0.6_after_energy_formation.csv", header=None)[0]

# Create DataFrame
df = pd.DataFrame({
    'DFT': dft,
    'POTENTIAL1': pot1,
    'POTENTIAL2': pot2,
    'POTENTIAL3': pot3,
    'POTENTIAL4': pot4
})

dft_ref = df['DFT']
potentials = ['POTENTIAL1', 'POTENTIAL2', 'POTENTIAL3', 'POTENTIAL4']

# Calculate R² scores
r2_results = {}

for pot in potentials:
    score = r2_score(dft_ref, df[pot])
    r2_results[pot] = score
    print(f"{pot} R² Score: {score:.8f}")

best_potential = max(r2_results, key=r2_results.get)
print(f"\nConclusion: {best_potential} is the best fit model.")

# Create 4 subplots
fig, axes = plt.subplots(2, 2, figsize=(8, 6))
axes = axes.flatten()

for i, pot in enumerate(potentials):

    axes[i].scatter(
        dft_ref,
        df[pot],
        color='blue',
        alpha=0.7,
        s=15,
        label='Data'
    )

    min_val = min(dft_ref.min(), df[pot].min())
    max_val = max(dft_ref.max(), df[pot].max())

    axes[i].plot(
        [min_val, max_val],
        [min_val, max_val],
        'r--',
        linewidth=2,
        label='y = x'
    )

    axes[i].set_title(f"{pot}\n$R^2$ = {r2_results[pot]:.6f}")
    axes[i].set_xlabel("DFT Force")
    axes[i].set_ylabel(f"{pot} Force")
    axes[i].grid(True, linestyle=':')
    axes[i].legend()

plt.tight_layout()
plt.show()
# Out:
# POTENTIAL1 R² Score: 0.86071395
# POTENTIAL2 R² Score: -4.38589384
# POTENTIAL3 R² Score: 0.91678909
# POTENTIAL4 R² Score: 0.75900023
#
# Conclusion: POTENTIAL3 is the best fit model.
